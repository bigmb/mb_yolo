# %%
## training a yolo model

# %%
from mb.yolo.train import train

# %%
train("./config.yaml")
# Out:
# New https://pypi.org/project/ultralytics/8.4.14 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.5 🚀 Python-3.11.6 torch-2.4.1+cu121 CPU (AMD Ryzen 9 3900XT 12-Core Processor)
# ...

# %%
from ultralytics import YOLO

# Load your model
model = YOLO('./yolo_project/run1/weights/best.onnx')

# Run inference
results = model('/home/malav/Downloads/datasets/weld_dataset/weld_defect_data/test/images/porosity-worm-hole-weld-defect-welding-process-flux-cored-arc-fcaw-204492534_jpeg_jpg.rf.c5201d1c888e3ffa1fded39930503d32.jpg')

# Process results
for result in results:
    print(result.boxes)  # Bounding boxes
    print(result.names)  # Class names
    result.show()  # Display results
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading yolo_project/run1/weights/best.onnx for ONNX Runtime inference...
#
# image 1/1 /home/malav/Downloads/datasets/weld_dataset/weld_defect_data/test/images/porosity-worm-hole-weld-defect-welding-process-flux-cored-arc-fcaw-204492534_jpeg_jpg.rf.c5201d1c888e3ffa1fded39930503d32.jpg: 640x640 1 Bad Weld, 5 Defects, 99.9ms
# Speed: 1.2ms preprocess, 99.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 2., 2., 2., 2., 2.])
# conf: tensor([0.8716, 0.4513, 0.4472, 0.3895, 0.3009, 0.2818])
# data: tensor([[5.0692e+01, 2.2904e+02, 5.4391e+02, 4.1687e+02, 8.7157e-01, 0.0000e+00],
#         [3.7457e+02, 3.1838e+02, 4.0331e+02, 3.5961e+02, 4.5134e-01, 2.0000e+00],
# ...

# %%
## add sam here

# %%
from mb_annotation.segsam2 import image_predictor

# %%
predictor = image_predictor('./sam2_hiera_s.yaml',
                            '/home/malav/Desktop/segment-anything-2/checkpoints/sam2_hiera_small.pt')

# %%
predictor.set_image('/home/malav/Downloads/datasets/weld_dataset/weld_defect_data/test/images/porosity-worm-hole-weld-defect-welding-process-flux-cored-arc-fcaw-204492534_jpeg_jpg.rf.c5201d1c888e3ffa1fded39930503d32.jpg')

# %%
result.names
# Out:
# {0: 'Bad Weld', 1: 'Good Weld', 2: 'Defect'}

# %%
result.boxes.cls
# Out:
# tensor([0., 2., 2., 2., 2., 2.])

# %%
import numpy as np
k1 = np.array(result.boxes.xywh[0],dtype=int)

x_min = k1[0]
y_min = k1[1]
x_max = k1[0] + k1[2]
y_max = k1[1] + k1 [3]

x_min /= predictor.image.shape[1]
y_min /= predictor.image.shape[0]
x_max /= predictor.image.shape[1]
y_max /= predictor.image.shape[0]

x_min, y_min, x_max, y_max
# Out:
# (0.4640625, 0.503125, 1.234375, 0.7953125)
